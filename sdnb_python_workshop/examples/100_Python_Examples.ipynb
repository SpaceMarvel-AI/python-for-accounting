# %% [markdown]
# # 🐍 100 Python Examples — Basic to Intermediate
# **SDNB Vaishnav College for Women, Chromepet**
# *Business Analytics Using Python — Reference Notebook*
#
# ---
#
# This notebook contains **100 short Python examples** (1–10 lines each), themed around accounting and commerce. Each example is in its own cell — run them in order, or jump to any section.
#
# | Section | Examples | Topic |
# |---------|----------|-------|
# | 1 | 1–15 | Print, variables, numbers, basic math |
# | 2 | 16–25 | Strings |
# | 3 | 26–35 | Input & type conversion |
# | 4 | 36–45 | Conditionals (`if/elif/else`, boolean logic) |
# | 5 | 46–55 | Lists |
# | 6 | 56–65 | Loops (`for`, `while`) |
# | 7 | 66–75 | Comprehensions, sorting, filtering |
# | 8 | 76–85 | Dictionaries, tuples, sets |
# | 9 | 86–95 | Functions |
# | 10 | 96–100 | Exceptions, files, modules |
#
# ### ▶️ How to run on Google Colab
# 1. Open Colab → **File → Upload notebook** → pick this `.ipynb`.
# 2. Press **Runtime → Run all**, or run any cell by clicking it and pressing **Shift + Enter**.
#
# > Examples 26–35 use `input()`. Each shows the live interactive line as a comment, plus a hardcoded version below it that runs without prompting.

# %% [markdown]
# ## 1️⃣ Print, Variables, Numbers, Basic Math (Examples 1–15)

# %%
# 1. Hello world
print("Hello, SDNB!")
# Out:
# Hello, SDNB!

# %%
# 2. Print multiple values separated by commas
print("Invoice", 2026, "amount", 4500)
# Out:
# Invoice 2026 amount 4500

# %%
# 3. Custom separator and ending
print("A", "B", "C", sep=" | ", end=".\n")
# Out:
# A | B | C.

# %%
# 4. Assign a variable
petty_cash = 500
print(petty_cash)
# Out:
# 500

# %%
# 5. Multiple assignment in one line
basic, hra, special = 25000, 10000, 5000
print(basic, hra, special)
# Out:
# 25000 10000 5000

# %%
# 6. Integer arithmetic
print(45 + 12 - 7 * 3)
# Out:
# 36

# %%
# 7. Float (decimal) arithmetic
print(2499.99 * 0.18)
# Out:
# 449.99819999999994

# %%
# 8. Floor division and modulo
print(47 // 12, 47 % 12)        # full cartons + leftover units
# Out:
# 3 11

# %%
# 9. Power operator
print(1.08 ** 5)                # CI growth factor at 8% over 5 years
# Out:
# 1.4693280768000005

# %%
# 10. Rounding for money
print(round(0.1 + 0.2, 2))      # → 0.3 (cleaned up)
# Out:
# 0.3

# %%
# 11. Check the type of a value
print(type(2499.99))            # → <class 'float'>
# Out:
# <class 'float'>

# %%
# 12. Convert int → float and back
print(float(45), int(99.7))
# Out:
# 45.0 99

# %%
# 13. f-string with a number
amount = 8499
print(f"Amount: ₹{amount}")
# Out:
# Amount: ₹8499

# %%
# 14. f-string with thousand separator and 2 decimals
gross = 1234567.5
print(f"₹{gross:,.2f}")         # → ₹1,234,567.50
# Out:
# ₹1,234,567.50

# %%
# 15. Constants and naming convention
GST_RATE = 0.18                 # ALL_CAPS = constant
print(GST_RATE)
# Out:
# 0.18

# %% [markdown]
# ## 2️⃣ Strings (Examples 16–25)

# %%
# 16. Concatenate strings with +
print("INV-" + "2026-" + "001")
# Out:
# INV-2026-001

# %%
# 17. Repeat a string
print("=" * 40)
# Out:
# ========================================

# %%
# 18. Length of a string
print(len("SDNB Vaishnav College"))
# Out:
# 21

# %%
# 19. Upper / lower case
print("sdnb".upper(), "CHENNAI".lower())
# Out:
# SDNB chennai

# %%
# 20. Strip whitespace
print("   Chennai   ".strip())
# Out:
# Chennai

# %%
# 21. Split a string into a list
print("Saree,Kurti,Bedsheet".split(","))
# Out:
# ['Saree', 'Kurti', 'Bedsheet']

# %%
# 22. Replace text
print("Invoice 2026".replace("2026", "2027"))
# Out:
# Invoice 2027

# %%
# 23. Slice a string
print("INV-2026-001"[4:8])      # → 2026
# Out:
# 2026

# %%
# 24. startswith / endswith / in
print("INV-2026".startswith("INV"), "saree" in "Silk saree pack")
# Out:
# True True

# %%
# 25. Multi-line string with triple quotes
note = """Dear Customer,
Your invoice is attached.
Regards, SDNB"""
print(note)
# Out:
# Dear Customer,
# Your invoice is attached.
# Regards, SDNB

# %% [markdown]
# ## 3️⃣ Input & Type Conversion (Examples 26–35)
#
# Each example shows the live `input()` form as a comment, then a hardcoded version below it that actually runs.

# %%
# 26. Read a name as text
# name = input("Your name: ")
name = "Priya"   # demo value
print("Welcome,", name)
# Out:
# Welcome, Priya

# %%
# 27. Read a number as int
# qty = int(input("Quantity: "))
qty = 12         # demo value
print("Total units:", qty)
# Out:
# Total units: 12

# %%
# 28. Read a price as float
# price = float(input("Price ₹: "))
price = 2499.99  # demo value
print(f"Recorded ₹{price:,.2f}")
# Out:
# Recorded ₹2,499.99

# %%
# 29. Mini GST calculator from user input
# bill = float(input("Bill amount: "))
bill = 6750
print(f"GST 18% = ₹{bill * 0.18:,.2f}")
# Out:
# GST 18% = ₹1,215.00

# %%
# 30. USD to INR converter
# usd = float(input("USD: "))
usd = 2500
print(f"INR = ₹{usd * 83.50:,.2f}")
# Out:
# INR = ₹208,750.00

# %%
# 31. Read two numbers and add
# a = float(input("a: ")); b = float(input("b: "))
a, b = 1500.0, 2300.0
print("Sum:", a + b)
# Out:
# Sum: 3800.0

# %%
# 32. Read 3 marks and compute average
# m1, m2, m3 = [int(input(f"Mark {i+1}: ")) for i in range(3)]
m1, m2, m3 = 78, 85, 91
print("Average:", (m1 + m2 + m3) / 3)
# Out:
# Average: 84.66666666666667

# %%
# 33. Simple Interest from user input
# p = float(input("Principal: "))
# r = float(input("Rate %: "))
# t = int(input("Years: "))
p, r, t = 100000, 8, 5
print("Simple Interest =", p * r * t / 100)
# Out:
# Simple Interest = 40000.0

# %%
# 34. Boolean from yes/no input
# answer = input("GST registered? (y/n) ").lower()
answer = "y"
print("Registered:", answer == "y")
# Out:
# Registered: True

# %%
# 35. Wrap input + arithmetic in one line
# print("Total:", float(input("Price: ")) * int(input("Qty: ")))
price, qty = 1299, 4
print("Total:", price * qty)
# Out:
# Total: 5196

# %% [markdown]
# ## 4️⃣ Conditionals (Examples 36–45)

# %%
# 36. Compare two numbers
revenue, target = 75000, 50000
print("Target met:", revenue >= target)
# Out:
# Target met: True

# %%
# 37. Logical AND / OR / NOT
salary, score = 32000, 720
print("Loan eligible:", salary > 25000 and score >= 700)
# Out:
# Loan eligible: True

# %%
# 38. if / else
age = 30
print("Adult" if age >= 18 else "Minor")
# Out:
# Adult

# %%
# 39. if / elif / else for grades
pct = 72
if pct >= 90:   grade = "O"
elif pct >= 75: grade = "A+"
elif pct >= 60: grade = "A"
else:           grade = "B"
print("Grade:", grade)
# Out:
# Grade: A

# %%
# 40. Ternary (one-line if/else)
stock = 8
status = "LOW" if stock < 10 else "OK"
print(status)
# Out:
# LOW

# %%
# 41. Truthy / falsy values
print(bool(0), bool(""), bool([]), bool("x"))
# Out:
# False False False True

# %%
# 42. is None check
email = None
print("Missing email" if email is None else email)
# Out:
# Missing email

# %%
# 43. Min / max of two
print(min(120, 90), max(120, 90))
# Out:
# 90 120

# %%
# 44. Absolute value
diff = 5000 - 7500
print("Loss:", abs(diff))
# Out:
# Loss: 2500

# %%
# 45. Chained comparison
mark = 67
print("Pass" if 40 <= mark < 80 else "Other")
# Out:
# Pass

# %% [markdown]
# ## 5️⃣ Lists (Examples 46–55)

# %%
# 46. Create a list
prices = [499, 1299, 2499, 799, 3999]
print(prices)
# Out:
# [499, 1299, 2499, 799, 3999]

# %%
# 47. Index access (positive and negative)
prices = [499, 1299, 2499, 799, 3999]
print(prices[0], prices[-1])
# Out:
# 499 3999

# %%
# 48. Slice a list
prices = [499, 1299, 2499, 799, 3999]
print(prices[1:4])
# Out:
# [1299, 2499, 799]

# %%
# 49. Append a new value
prices = [499, 1299, 2499]
prices.append(599)
print(prices)
# Out:
# [499, 1299, 2499, 599]

# %%
# 50. Remove a value
prices = [499, 1299, 2499, 799]
prices.remove(799)
print(prices)
# Out:
# [499, 1299, 2499]

# %%
# 51. Sort ascending and descending
prices = [499, 1299, 2499, 799, 3999]
prices.sort()
print(prices)
prices.sort(reverse=True)
print(prices)
# Out:
# [499, 799, 1299, 2499, 3999]
# [3999, 2499, 1299, 799, 499]

# %%
# 52. Reverse in place
nums = [1, 2, 3]
nums.reverse()
print(nums)
# Out:
# [3, 2, 1]

# %%
# 53. Built-in summaries
prices = [499, 1299, 2499, 799, 3999]
print(sum(prices), min(prices), max(prices), len(prices))
# Out:
# 9095 499 3999 5

# %%
# 54. Average of a list
prices = [499, 1299, 2499, 799, 3999]
print(sum(prices) / len(prices))
# Out:
# 1819.0

# %%
# 55. Membership test
prices = [499, 1299, 2499]
print(2499 in prices)
# Out:
# True

# %% [markdown]
# ## 6️⃣ Loops (Examples 56–65)

# %%
# 56. for over a list
for p in [499, 1299, 2499]:
    print(f"₹{p}")
# Out:
# ₹499
# ₹1299
# ₹2499

# %%
# 57. for with enumerate
for i, m in enumerate(["Apr", "May", "Jun"], 1):
    print(i, m)
# Out:
# 1 Apr
# 2 May
# 3 Jun

# %%
# 58. for over range
for n in range(1, 6):
    print("Day", n)
# Out:
# Day 1
# Day 2
# Day 3
# Day 4
# Day 5

# %%
# 59. for with a step
for n in range(0, 21, 5):
    print(n)
# Out:
# 0
# 5
# 10
# 15
# 20

# %%
# 60. while loop
balance = 10000
while balance > 0:
    balance -= 2500
    print("Remaining:", balance)
# Out:
# Remaining: 7500
# Remaining: 5000
# Remaining: 2500
# Remaining: 0

# %%
# 61. Break out of a loop
for n in range(1, 100):
    if n > 5:
        break
    print(n)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# 62. continue (skip iteration)
for n in range(1, 6):
    if n == 3:
        continue
    print(n)
# Out:
# 1
# 2
# 4
# 5

# %%
# 63. Nested loops — multiplication grid
for q in [10, 50, 100]:
    for d in [0, 5, 10]:
        print(q, d, q * (1 - d / 100))
# Out:
# 10 0 10.0
# 10 5 9.5
# 10 10 9.0
# 50 0 50.0
# 50 5 47.5
# 50 10 45.0
# 100 0 100.0
# 100 5 95.0
# 100 10 90.0

# %%
# 64. Sum with a for loop
total = 0
for s in [3450, 1200, 5400, 2780, 950]:
    total += s
print("Total:", total)
# Out:
# Total: 13780

# %%
# 65. Count items meeting a condition
sales = [3450, 1200, 5400, 2780, 950]
above = sum(1 for s in sales if s > 2000)
print("Sales above ₹2,000:", above)
# Out:
# Sales above ₹2,000: 3

# %% [markdown]
# ## 7️⃣ Comprehensions, Sorting, Filtering (Examples 66–75)

# %%
# 66. List comprehension — squares
print([n * n for n in range(1, 6)])
# Out:
# [1, 4, 9, 16, 25]

# %%
# 67. Add GST to every price
prices = [499, 1299, 2499]
print([round(p * 1.18, 2) for p in prices])
# Out:
# [588.82, 1532.82, 2948.82]

# %%
# 68. Conditional comprehension
print([p for p in [499, 1299, 2499, 99] if p > 500])
# Out:
# [1299, 2499]

# %%
# 69. Build a list of strings
prices = [499, 1299, 2499]
print([f"₹{p:,}" for p in prices])
# Out:
# ['₹499', '₹1,299', '₹2,499']

# %%
# 70. Sum via comprehension
prices = [499, 1299, 2499]
print(sum(p for p in prices))
# Out:
# 4297

# %%
# 71. sorted() with a key (case-insensitive)
names = ["priya", "ARUN", "kavitha"]
print(sorted(names, key=str.lower))
# Out:
# ['ARUN', 'kavitha', 'priya']

# %%
# 72. sorted() of dicts by a field
sales = [{"prod": "Saree", "amt": 2499}, {"prod": "Kurti", "amt": 1299}]
print(sorted(sales, key=lambda r: r["amt"], reverse=True))
# Out:
# [{'prod': 'Saree', 'amt': 2499}, {'prod': 'Kurti', 'amt': 1299}]

# %%
# 73. filter() with a lambda
prices = [499, 1299, 2499]
print(list(filter(lambda p: p > 1000, prices)))
# Out:
# [1299, 2499]

# %%
# 74. map() with a lambda
prices = [499, 1299, 2499]
print(list(map(lambda p: round(p * 1.18, 2), prices)))
# Out:
# [588.82, 1532.82, 2948.82]

# %%
# 75. Combine two lists with zip()
months = ["Jan", "Feb", "Mar"]
revenue = [120000, 150000, 175000]
print(list(zip(months, revenue)))
# Out:
# [('Jan', 120000), ('Feb', 150000), ('Mar', 175000)]

# %% [markdown]
# ## 8️⃣ Dictionaries, Tuples, Sets (Examples 76–85)

# %%
# 76. Create a dictionary (customer record)
customer = {"name": "Priya", "balance": 45000, "city": "Chennai"}
print(customer)
# Out:
# {'name': 'Priya', 'balance': 45000, 'city': 'Chennai'}

# %%
# 77. Access by key
customer = {"name": "Priya", "balance": 45000}
print(customer["name"])
# Out:
# Priya

# %%
# 78. Update / add a key
customer = {"name": "Priya", "balance": 45000}
customer["balance"] = 47500
customer["email"] = "priya@example.com"
print(customer)
# Out:
# {'name': 'Priya', 'balance': 47500, 'email': 'priya@example.com'}

# %%
# 79. Safe get with default
customer = {"name": "Priya"}
print(customer.get("phone", "N/A"))
# Out:
# N/A

# %%
# 80. Loop over keys, values, items
customer = {"name": "Priya", "balance": 45000, "city": "Chennai"}
for key, val in customer.items():
    print(key, "=", val)
# Out:
# name = Priya
# balance = 45000
# city = Chennai

# %%
# 81. Dict comprehension — square map
print({n: n * n for n in range(1, 6)})
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# 82. Count word frequency with a dict
words = "saree kurti saree bedsheet kurti saree".split()
freq = {}
for w in words:
    freq[w] = freq.get(w, 0) + 1
print(freq)
# Out:
# {'saree': 3, 'kurti': 2, 'bedsheet': 1}

# %%
# 83. Tuple — fixed pair (immutable)
point = ("Chennai", 600044)
print(point[0], point[1])
# Out:
# Chennai 600044

# %%
# 84. Tuple unpacking
city, pin = ("Chennai", 600044)
print(city, pin)
# Out:
# Chennai 600044

# %%
# 85. Sets and union/intersection
a = {"saree", "kurti", "watch"}
b = {"watch", "bedsheet"}
print(a | b, a & b)              # union, intersection
# Out:
# {'kurti', 'bedsheet', 'saree', 'watch'} {'watch'}

# %% [markdown]
# ## 9️⃣ Functions (Examples 86–95)

# %%
# 86. Define and call a function
def greet(name):
    print(f"Welcome, {name}!")
greet("Priya")
# Out:
# Welcome, Priya!

# %%
# 87. Return a value
def add_gst(price, rate=0.18):
    return round(price * (1 + rate), 2)
print(add_gst(2499))
# Out:
# 2948.82

# %%
# 88. Function with default parameter
def discount(price, pct=10):
    return price - price * pct / 100
print(discount(2499), discount(2499, 25))
# Out:
# 2249.1 1874.25

# %%
# 89. Multiple return values
def stats(nums):
    return min(nums), max(nums), sum(nums) / len(nums)
print(stats([3450, 1200, 5400]))
# Out:
# (1200, 5400, 3350.0)

# %%
# 90. *args (any number of arguments)
def total(*amounts):
    return sum(amounts)
print(total(100, 200, 300, 400))
# Out:
# 1000

# %%
# 91. **kwargs (keyword arguments)
def invoice(**fields):
    for k, v in fields.items():
        print(k, ":", v)
invoice(no="INV-001", amount=4500, gst=810)
# Out:
# no : INV-001
# amount : 4500
# gst : 810

# %%
# 92. Lambda (anonymous function)
square = lambda x: x * x
print(square(7))
# Out:
# 49

# %%
# 93. Recursion — factorial
def fact(n):
    return 1 if n <= 1 else n * fact(n - 1)
print(fact(5))
# Out:
# 120

# %%
# 94. Nested functions / closures
def make_taxer(rate):
    def add_tax(p):
        return p * (1 + rate)
    return add_tax
gst = make_taxer(0.18)
print(round(gst(2499), 2))
# Out:
# 2948.82

# %%
# 95. Docstring on a function
def margin(rev, cost):
    """Return profit margin in %."""
    return (rev - cost) / rev * 100
print(round(margin(28_50_000, 17_10_000), 2))
# Out:
# 40.0

# %% [markdown]
# ## 🔟 Exceptions, Files, Modules (Examples 96–100)

# %%
# 96. try / except for safe input parsing
try:
    n = int("ABC")               # this fails on purpose
except ValueError:
    print("Not a valid number")
# Out:
# Not a valid number

# %%
# 97. try / except / finally
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")
finally:
    print("Cleanup done")
# Out:
# Cannot divide by zero
# Cleanup done

# %%
# 98. Write a small text file
with open("hello.txt", "w") as f:
    f.write("SDNB Workshop notes\nLine 2\n")
print("✅ wrote hello.txt")
# Out:
# ✅ wrote hello.txt

# %%
# 99. Read it back, line by line
with open("hello.txt") as f:
    for line in f:
        print(line.strip())
# Out:
# SDNB Workshop notes
# Line 2

# %%
# 100. Use built-in modules
import math, datetime, random
print(math.sqrt(16), datetime.date.today(), random.randint(1, 100))
# Out:
# 4.0 2026-04-28 26

# %% [markdown]
# ## 🎓 You did it!
#
# If you've worked through all 100, you now know:
#
# - ✅ How to print, store and format data
# - ✅ How to manipulate text and numbers
# - ✅ How to take input and make decisions
# - ✅ How to work with lists, dicts, tuples, sets
# - ✅ How to write loops and comprehensions
# - ✅ How to build and call functions (including `*args`, lambdas, recursion, closures)
# - ✅ How to handle errors, read & write files, and use built-in modules
#
# You're ready to move on to the **main workshop notebooks** in the same folder:
# **Day1 → Day2 → Day3 → Day4 → Capstone.**
